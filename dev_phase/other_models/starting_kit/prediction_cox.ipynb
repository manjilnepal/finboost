# %% [markdown]
# # FinSurvival Competition: Starter Notebook (Cox Model Prediction Submission)
#
# **Objective:** This notebook provides a workflow for creating a valid prediction submission using the `CoxPHFitter` model. The competition requires you to submit a `.zip` file containing 16 separate prediction files in CSV format.
#
# This notebook will guide you through:
# 1.  Loading the training and test sets for each of the 16 tasks from a single directory.
# 2.  Training a model (using `CoxPHFitter` as an example).
# 3.  Generating predictions on the test set in the required format.
# 4.  Saving each set of predictions to a correctly named CSV file.
# 5.  Zipping all 16 prediction files for submission.

# %% [markdown]
# ## Step 1: Setup and Imports

# %%
# Install required packages
# pip install -q pandas lifelines==0.27.8 scikit-learn==1.2.2 scikit-survival==0.21.0 numpy

# Import libraries
import pandas as pd
import numpy as np
import os
import shutil
from lifelines import CoxPHFitter
from lifelines.exceptions import ConvergenceError
from sklearn.preprocessing import StandardScaler
from typing import Tuple, Optional

# %% [markdown]
# ## Step 2: Define a Preprocessing Function
#
# Even though you are not submitting this code, you will still need a preprocessing pipeline to train your models effectively. You can use the one below as a starting point.

# %%
def preprocess(
    train_df_with_labels: pd.DataFrame,
    test_features_df: Optional[pd.DataFrame] = None,
) -> Tuple[pd.DataFrame, pd.DataFrame, Optional[pd.DataFrame]]:
    """
    Preprocesses data for the competition.
    """
    train_targets = train_df_with_labels[["timeDiff", "status"]]
    train_features = train_df_with_labels.drop(columns=["timeDiff", "status"])
    cols_to_drop = ["id", "user", "pool", "Index Event", "Outcome Event", "type", "timestamp"]
    train_features = train_features.drop(columns=cols_to_drop, errors="ignore")
    categorical_cols = train_features.select_dtypes(include=["object", "category"]).columns
    for col in categorical_cols:
        top_categories = train_features[col].value_counts().nlargest(10).index
        train_features[col] = train_features[col].where(train_features[col].isin(top_categories), "Other")
    train_features_encoded = pd.get_dummies(train_features, columns=categorical_cols, dummy_na=True, drop_first=True)
    numerical_cols = train_features_encoded.select_dtypes(include=np.number).columns
    scaler = StandardScaler()
    train_features_scaled = scaler.fit_transform(train_features_encoded[numerical_cols])
    train_features_final = pd.DataFrame(train_features_scaled, index=train_features_encoded.index, columns=numerical_cols).fillna(0)
    cols_to_keep = train_features_final.columns[train_features_final.var() != 0]
    train_features_final = train_features_final[cols_to_keep]
    test_processed_features = None
    if test_features_df is not None:
        test_features = test_features_df.drop(columns=cols_to_drop, errors="ignore")
        for col in categorical_cols:
            top_categories = train_features[col].value_counts().nlargest(10).index
            test_features[col] = test_features[col].where(test_features[col].isin(top_categories), "Other")
        test_features_encoded = pd.get_dummies(test_features, columns=categorical_cols, dummy_na=True, drop_first=True)
        train_cols = train_features_encoded.columns
        test_features_aligned = test_features_encoded.reindex(columns=train_cols, fill_value=0)
        test_features_scaled = scaler.transform(test_features_aligned[numerical_cols])
        test_features_final = pd.DataFrame(test_features_scaled, index=test_features_aligned.index, columns=numerical_cols).fillna(0)
        test_processed_features = test_features_final[cols_to_keep]
    return train_features_final, train_targets, test_processed_features

# %% [markdown]
# ## Step 3: Loop, Train, and Save Predictions
#
# This is the main part of the notebook. We will loop through all 16 tasks. For each task, we will:
# 1. Load the training data and the test features.
# 2. Preprocess both.
# 3. Train a model on the training data.
# 4. Generate predictions on the processed test features.
# 5. Save the predictions to a CSV file with the correct name.

# %%
# Define path to the single participant data folder.
PARTICIPANT_DATA_PATH = '../participant_data/'
SUBMISSION_DIR = 'my_prediction_submission_cox'
os.makedirs(SUBMISSION_DIR, exist_ok=True)

# Define all 16 event pairs
index_events = ["Borrow", "Deposit", "Repay", "Withdraw"]
outcome_events = index_events + ["Liquidated"]
event_pairs = []
for index_event in index_events:
    for outcome_event in outcome_events:
        if index_event == outcome_event:
            continue
        event_pairs.append((index_event, outcome_event))

for index_event, outcome_event in event_pairs:
    print(f"\n{'='*50}")
    print(f"Processing and Predicting for: {index_event} -> {outcome_event}")
    print(f"{'='*50}")
    
    dataset_path = os.path.join(index_event, outcome_event)
    
    # --- Load and Preprocess ---
    try:
        train_df = pd.read_csv(os.path.join(PARTICIPANT_DATA_PATH, dataset_path, 'train.csv'))
        # The test features for participants are the validation features.
        test_features_df = pd.read_csv(os.path.join(PARTICIPANT_DATA_PATH, dataset_path, 'test_features.csv'))
    except FileNotFoundError as e:
        print(f"Data not found for {dataset_path}. Skipping.")
        continue
        
    X_train, y_train, X_test_processed = preprocess(train_df, test_features_df)

    # --- Train Model ---
    try:
        lifelines_train_df = pd.concat([X_train, y_train.reset_index(drop=True)], axis=1)
        model = CoxPHFitter(penalizer=0.1)
        
        try:
            # First attempt to fit the model with standard parameters
            model.fit(lifelines_train_df, duration_col='timeDiff', event_col='status')
        except ConvergenceError:
            # If it fails, try again with a stronger penalizer and smaller step size
            print("  - Standard model failed to converge. Trying robust parameters...")
            model = CoxPHFitter(penalizer=1.0)
            model.fit(lifelines_train_df, duration_col='timeDiff', event_col='status', fit_options={'step_size': 0.1})
            print("  - Successfully converged with robust parameters.")

        # --- Generate and Save Predictions ---
        print(f"Generating predictions for {dataset_path}...")
        predictions = -model.predict_partial_hazard(X_test_processed)
        
        # Save predictions to a CSV file
        prediction_filename = dataset_path.replace(os.sep, '_') + '.csv'
        prediction_save_path = os.path.join(SUBMISSION_DIR, prediction_filename)
        pd.DataFrame(predictions).to_csv(prediction_save_path, header=False, index=False)
        print(f"  -> Predictions saved to {prediction_save_path}")
        
    except (ConvergenceError, ValueError) as e:
        print(f"\nERROR: The model for {dataset_path} failed to train even with robust parameters. No prediction file will be created.")
        print(f"Details: {e}")

print("\n\nAll prediction files have been generated.")
# Out:
# ==================================================
# Processing and Predicting for: Borrow -> Deposit
# ==================================================
# Generating predictions for Borrow/Deposit...
#   -> Predictions saved to my_prediction_submission_cox/Borrow_Deposit.csv
#
# ==================================================
# Processing and Predicting for: Borrow -> Repay
# ==================================================
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1789: RuntimeWarning: overflow encountered in exp
#   scores = weights * exp(dot(X, beta))
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1837: RuntimeWarning: invalid value encountered in multiply
#   numer = risk_phi_x - multiply.outer(increasing_proportion, tie_phi_x)
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1837: RuntimeWarning: invalid value encountered in subtract
#   numer = risk_phi_x - multiply.outer(increasing_proportion, tie_phi_x)
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1838: RuntimeWarning: invalid value encountered in multiply
#   denom = 1.0 / (risk_phi - increasing_proportion * tie_phi)
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1838: RuntimeWarning: invalid value encountered in subtract
#   denom = 1.0 / (risk_phi - increasing_proportion * tie_phi)
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1854: RuntimeWarning: invalid value encountered in multiply
#   summand = numer * denom[:, None]
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1861: RuntimeWarning: divide by zero encountered in log
#   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1852: RuntimeWarning: invalid value encountered in multiply
#   a1 = risk_phi_x_x * denom
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1807: RuntimeWarning: invalid value encountered in add
#   risk_phi_x = risk_phi_x + (phi_x_i).sum(0)
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1808: RuntimeWarning: invalid value encountered in add
#   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# /home/dgxuser40/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/utils/__init__.py:1120: ConvergenceWarning: Column userBorrowSum have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
#
# >>> events = df['status'].astype(bool)
# >>> print(df.loc[events, 'userBorrowSum'].var())
# >>> print(df.loc[~events, 'userBorrowSum'].var())
#
# A very low variance means that the column userBorrowSum completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
#
#   warnings.warn(dedent(warning_text), ConvergenceWarning)
#   - Standard model failed to converge. Trying robust parameters...
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1530, in SemiParametricPHFitter._newton_raphson_for_efron_model(self, X, T, E, weights, entries, initial_point, show_progress, step_size, precision, r_precision, max_steps)
#    1529 try:
# -> 1530     inv_h_dot_g_T = spsolve(-h, g, assume_a="pos", check_finite=False)
#    1531 except (ValueError, LinAlgError) as e:
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/scipy/_lib/_util.py:1233, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1232 if not any(batch_shapes):
# -> 1233     return f(*arrays, *other_args, **kwargs)
#    1235 # Determine broadcasted batch shape
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/scipy/linalg/_basic.py:344, in solve(a, b, lower, overwrite_a, overwrite_b, check_finite, assume_a, transposed)
#     342     rcond, info = pocon(lu, anorm)
# --> 344 _solve_check(n, info, lamch, rcond)
#     346 if b_is_1D:
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/scipy/linalg/_basic.py:43, in _solve_check(n, info, lamch, rcond)
#      42 elif 0 < info or rcond == 0:
# ---> 43     raise LinAlgError('Matrix is singular.')
#      45 if lamch is None:
#
# LinAlgError: Matrix is singular.
#
# During handling of the above exception, another exception occurred:
#
# ConvergenceError                          Traceback (most recent call last)
# Cell In[6], line 41
#      39 try:
#      40     # First attempt to fit the model with standard parameters
# ---> 41     model.fit(lifelines_train_df, duration_col='timeDiff', event_col='status')
#      42 except ConvergenceError:
#      43     # If it fails, try again with a stronger penalizer and smaller step size
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/utils/__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      55 cls.set_censoring_type(model, cls.RIGHT)
# ---> 56 return function(model, *args, **kwargs)
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:290, in CoxPHFitter.fit(self, df, duration_col, event_col, show_progress, initial_point, strata, weights_col, cluster_col, robust, batch_mode, timeline, formula, entry_col, fit_options)
#     289 self.strata = utils._to_list_or_singleton(utils.coalesce(strata, self.strata))
# --> 290 self._model = self._fit_model(
#     291     df,
#     292     duration_col,
#     293     event_col=event_col,
#     294     show_progress=show_progress,
#     295     initial_point=initial_point,
#     296     strata=self.strata,
#     297     weights_col=weights_col,
#     298     cluster_col=cluster_col,
#     299     robust=robust,
#     300     batch_mode=batch_mode,
#     301     timeline=timeline,
#     302     formula=formula,
#     303     entry_col=entry_col,
#     304     fit_options=fit_options,
#     305 )
#     306 return self
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:610, in CoxPHFitter._fit_model(self, *args, **kwargs)
#     609 if self.baseline_estimation_method == "breslow":
# --> 610     return self._fit_model_breslow(*args, **kwargs)
#     611 elif self.baseline_estimation_method == "spline":
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:623, in CoxPHFitter._fit_model_breslow(self, *args, **kwargs)
#     622 if utils.CensoringType.is_right_censoring(self):
# --> 623     model.fit(*args, **kwargs)
#     624     return model
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/utils/__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      55 cls.set_censoring_type(model, cls.RIGHT)
# ---> 56 return function(model, *args, **kwargs)
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1252, in SemiParametricPHFitter.fit(self, df, duration_col, event_col, show_progress, initial_point, strata, weights_col, cluster_col, robust, batch_mode, timeline, formula, entry_col, fit_options)
#    1248 X_norm = pd.DataFrame(
#    1249     utils.normalize(X.values, self._norm_mean.values, self._norm_std.values), index=X.index, columns=X.columns
#    1250 )
# -> 1252 params_, ll_, variance_matrix_, baseline_hazard_, baseline_cumulative_hazard_, model = self._fit_model(
#    1253     X_norm,
#    1254     T,
#    1255     E,
#    1256     weights=weights,
#    1257     entries=entries,
#    1258     fit_options=utils.coalesce(fit_options, dict()),
#    1259     initial_point=initial_point,
#    1260     show_progress=show_progress,
#    1261 )
#    1263 self.log_likelihood_ = ll_
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1380, in SemiParametricPHFitter._fit_model(self, X, T, E, weights, entries, fit_options, initial_point, show_progress)
#    1369 def _fit_model(
#    1370     self,
#    1371     X: DataFrame,
#    (...)   1378     show_progress: bool = True,
#    1379 ):
# -> 1380     beta_, ll_, hessian_ = self._newton_raphson_for_efron_model(
#    1381         X,
#    1382         T,
#    1383         E,
#    1384         weights,
#    1385         entries,
#    1386         initial_point=initial_point,
#    1387         show_progress=show_progress,
#    1388         **fit_options,
#    1389     )
#    1391     # compute the baseline hazard here.
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1539, in SemiParametricPHFitter._newton_raphson_for_efron_model(self, X, T, E, weights, entries, initial_point, show_progress, step_size, precision, r_precision, max_steps)
#    1538 elif isinstance(e, LinAlgError):
# -> 1539     raise exceptions.ConvergenceError(
#    1540         """Convergence halted due to matrix inversion problems. Suspicion is high collinearity. {0}""".format(
#    1541             CONVERGENCE_DOCS
#    1542         ),
#    1543         e,
#    1544     )
#    1545 else:
#    1546     # something else?
#
# ConvergenceError: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 46
#      44     print("  - Standard model failed to converge. Trying robust parameters...")
#      45     model = CoxPHFitter(penalizer=1.0)
# ---> 46     model.fit(lifelines_train_df, duration_col='timeDiff', event_col='status', fit_options={'step_size': 0.1})
#      47     print("  - Successfully converged with robust parameters.")
#      49 # --- Generate and Save Predictions ---
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/utils/__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      53 @wraps(function)
#      54 def f(model, *args, **kwargs):
#      55     cls.set_censoring_type(model, cls.RIGHT)
# ---> 56     return function(model, *args, **kwargs)
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:290, in CoxPHFitter.fit(self, df, duration_col, event_col, show_progress, initial_point, strata, weights_col, cluster_col, robust, batch_mode, timeline, formula, entry_col, fit_options)
#     184 """
#     185 Fit the Cox proportional hazard model to a right-censored dataset. Alias of `fit_right_censoring`.
#     186
#    (...)    287
#     288 """
#     289 self.strata = utils._to_list_or_singleton(utils.coalesce(strata, self.strata))
# --> 290 self._model = self._fit_model(
#     291     df,
#     292     duration_col,
#     293     event_col=event_col,
#     294     show_progress=show_progress,
#     295     initial_point=initial_point,
#     296     strata=self.strata,
#     297     weights_col=weights_col,
#     298     cluster_col=cluster_col,
#     299     robust=robust,
#     300     batch_mode=batch_mode,
#     301     timeline=timeline,
#     302     formula=formula,
#     303     entry_col=entry_col,
#     304     fit_options=fit_options,
#     305 )
#     306 return self
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:610, in CoxPHFitter._fit_model(self, *args, **kwargs)
#     608 def _fit_model(self, *args, **kwargs):
#     609     if self.baseline_estimation_method == "breslow":
# --> 610         return self._fit_model_breslow(*args, **kwargs)
#     611     elif self.baseline_estimation_method == "spline":
#     612         return self._fit_model_spline(*args, **kwargs)
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:623, in CoxPHFitter._fit_model_breslow(self, *args, **kwargs)
#     619 model = SemiParametricPHFitter(
#     620     penalizer=self.penalizer, l1_ratio=self.l1_ratio, strata=self.strata, alpha=self.alpha, label=self._label
#     621 )
#     622 if utils.CensoringType.is_right_censoring(self):
# --> 623     model.fit(*args, **kwargs)
#     624     return model
#     625 else:
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/utils/__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      53 @wraps(function)
#      54 def f(model, *args, **kwargs):
#      55     cls.set_censoring_type(model, cls.RIGHT)
# ---> 56     return function(model, *args, **kwargs)
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1252, in SemiParametricPHFitter.fit(self, df, duration_col, event_col, show_progress, initial_point, strata, weights_col, cluster_col, robust, batch_mode, timeline, formula, entry_col, fit_options)
#    1247 # this is surprisingly faster to do...
#    1248 X_norm = pd.DataFrame(
#    1249     utils.normalize(X.values, self._norm_mean.values, self._norm_std.values), index=X.index, columns=X.columns
#    1250 )
# -> 1252 params_, ll_, variance_matrix_, baseline_hazard_, baseline_cumulative_hazard_, model = self._fit_model(
#    1253     X_norm,
#    1254     T,
#    1255     E,
#    1256     weights=weights,
#    1257     entries=entries,
#    1258     fit_options=utils.coalesce(fit_options, dict()),
#    1259     initial_point=initial_point,
#    1260     show_progress=show_progress,
#    1261 )
#    1263 self.log_likelihood_ = ll_
#    1264 self.model = model
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1380, in SemiParametricPHFitter._fit_model(self, X, T, E, weights, entries, fit_options, initial_point, show_progress)
#    1369 def _fit_model(
#    1370     self,
#    1371     X: DataFrame,
#    (...)   1378     show_progress: bool = True,
#    1379 ):
# -> 1380     beta_, ll_, hessian_ = self._newton_raphson_for_efron_model(
#    1381         X,
#    1382         T,
#    1383         E,
#    1384         weights,
#    1385         entries,
#    1386         initial_point=initial_point,
#    1387         show_progress=show_progress,
#    1388         **fit_options,
#    1389     )
#    1391     # compute the baseline hazard here.
#    1392     predicted_partial_hazards_ = (
#    1393         pd.DataFrame(np.exp(dot(X, beta_)), columns=["P"]).assign(T=T.values, E=E.values, W=weights.values).set_index(X.index)
#    1394     )
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1506, in SemiParametricPHFitter._newton_raphson_for_efron_model(self, X, T, E, weights, entries, initial_point, show_progress, step_size, precision, r_precision, max_steps)
#    1502 i += 1
#    1504 if self.strata is None:
# -> 1506     h, g, ll_ = get_gradients(X, T, E, weights, entries, beta)
#    1508 else:
#    1509     g = np.zeros_like(beta)
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/lifelines/fitters/coxph_fitter.py:1806, in SemiParametricPHFitter._get_efron_values_batch(self, X, T, E, weights, entries, beta)
#    1803 phi_x_x_i = dot(X_at_t.T, phi_x_i)
#    1805 # Calculate sums of Risk set
# -> 1806 risk_phi = risk_phi + phi_i.sum()
#    1807 risk_phi_x = risk_phi_x + (phi_x_i).sum(0)
#    1808 risk_phi_x_x = risk_phi_x_x + phi_x_x_i
#
# File ~/miniconda3/envs/finsurv/lib/python3.11/site-packages/numpy/_core/_methods.py:51, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
# ---> 51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 4: Create the Submission ZIP file
#
# The final step is to package all 16 of your prediction CSV files into a single `submission.zip` file.

# %%
output_zip_filename = 'submission_cox'
shutil.make_archive(output_zip_filename, 'zip', SUBMISSION_DIR)

print(f"Successfully created '{output_zip_filename}.zip' from the '{SUBMISSION_DIR}' directory.")
print("You can now upload this file to the CodaBench competition.")
# Out:
# Successfully created 'submission_cox.zip' from the 'my_prediction_submission_cox' directory.
# You can now upload this file to the CodaBench competition.
