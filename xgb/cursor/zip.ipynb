# %%
import os
import shutil

# %%
output_zip_filename = f'cur_0.05_500_boost_xgb'
shutil.make_archive(output_zip_filename, 'zip', "/home/dgxuser40/manjil/finsurv/xgb/cursor/cur_0.05_500_boost_xgb")
print(f"Successfully created!!")
print("You can now upload this file to the CodaBench competition.")
# Out:
# Successfully created!!
# You can now upload this file to the CodaBench competition.
